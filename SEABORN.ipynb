# %%
# loading the required dependancies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %% [markdown]
# # Numerical Data Plotting

# %%
# loading the dataset in use
dataset = pd.read_csv('D:/ML/data/tips.csv')

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = sb.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.set(style='darkgrid')

# %%
# relational plotting
sb.relplot(x = 'total_bill',y = 'tip',data = df)

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, hue = 'smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, hue = 'size',palette = 'ch:r= -0.8,l=0.96')

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, style = 'size',palette = 'ch:r= -0.8,l=0.96')

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, size = 'day',palette = 'ch:r= -0.8,l=0.96')

# %%
dataframe = pd.DataFrame(dict(time = np.arange(500),value = np.random.randn(500).cumsum()))
sb.relplot(x = 'time',y = 'value',data = dataframe, kind = 'line')

# %%
fmri = sb.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sb.relplot(x = 'timepoint',y = 'signal',data = fmri, kind = 'line')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.relplot(x = 'timepoint',y = 'signal',data = fmri, kind = 'line',ci = False)

# %%
sb.relplot(x = 'timepoint',y = 'signal',data = fmri, kind = 'line',ci = 'sd')

# %%
sb.relplot(x = 'timepoint',y = 'signal',estimator = None,data = fmri, kind = 'line',ci = False)

# %%
sb.relplot(x = 'timepoint',y = 'signal',hue = 'event',data = fmri, kind = 'line',ci = False)

# %%
sb.relplot(x = 'timepoint',y = 'signal',style = 'event',data = fmri, kind = 'line',ci = False,markers = True)

# %%
sb.relplot(x = 'timepoint',y = 'signal',size = 'event',data = fmri, kind = 'line',ci = False)

# %%
fmri['event'].value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
sb.relplot(x = 'timepoint',y = 'signal',hue = 'region',data = fmri, kind = 'line',units = 'subject',estimator = None)

# %%
sb.relplot(x = 'timepoint',y = 'signal',hue = 'region',data = fmri.query("event == 'stim'"), kind = 'line',units = 'subject',estimator = None)

# %%
dots = sb.load_dataset('dots')
dots = dots.query("align == 'dots'")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
p = sb.cubehelix_palette(light= 0.5,n_colors= 6)
sb.relplot(x = 'time',y = 'firing_rate',data = dots, kind = 'line',hue = 'coherence', style = 'choice',palette= p)

# %%
dataset = pd.DataFrame(dict(time = pd.date_range('01-01-2020',periods= 365), value = np.random.randn(365)))
dataset.head()
# Out:
#         time     value
# 0 2020-01-01 -0.204339
# 1 2020-01-02 -0.217576
# 2 2020-01-03 -0.357284
# 3 2020-01-04  0.822375
# 4 2020-01-05  1.916446

# %%
sb.relplot(x = 'time',y = 'value', data = dataset,kind = 'line')

# %%
m = sb.relplot(x = 'time',y = 'value', data = dataset,kind = 'line')
m.fig.autofmt_xdate()

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, hue = 'smoker',col = 'time')

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, hue = 'smoker',row = 'time')

# %%
sb.relplot(x = 'timepoint',y = 'signal',hue = 'subject',data = fmri, kind = 'line',col = 'region', row = 'event', height = 5,estimator = None)

# %%
sb.relplot(x = 'total_bill',y = 'tip',data = df, hue = 'smoker',col = 'size',col_wrap = 3, height = 5)

# %%
df['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
# line plotting
sb.lineplot(x = 'timepoint',y = 'signal',data = fmri, hue = 'region',style = 'event',markers = True,err_style= 'bars',ci = 70)

# %%
# scatter plotting
iris = sb.load_dataset('iris')
sb.scatterplot(x = 'sepal_length',y = 'petal_width',data = iris)

# %% [markdown]
# # Categorical Data Plotting

# %%
titanic = sb.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Catplot
sb.catplot(x = 'day', y = 'total_bill', data = df)

# %%
sb.catplot(x = 'day', y = 'total_bill', data = df,jitter = False)

# %%
sb.catplot(x = 'day', y = 'total_bill', data = df,kind = 'swarm',hue = 'sex')

# %%
# Box plotting
sb.catplot(x = 'day', y = 'total_bill', data = df,kind = 'box',hue = 'sex')

# %%
sb.catplot(x = 'day', y = 'total_bill', data = df,kind = 'box',hue = 'sex', dodge = False)

# %%
sb.catplot(x = 'day', y = 'total_bill', data = df,kind = 'boxen', dodge = False)

# %%
sb.boxenplot(x = 'day', y = 'total_bill', data = df, dodge = False)

# %%
# Violin plotting
sb.catplot(x = 'total_bill',y = 'day',hue = 'time', kind = 'violin',data = df)

# %%
sb.catplot(x = 'total_bill',y = 'day',hue = 'sex', kind = 'violin',data = df,split = True)

# %%
v =sb.catplot(y = 'total_bill',x = 'day', kind = 'violin',inner = None,data = df)
sb.swarmplot(y = 'total_bill',x = 'day',color = 'k',size = 4,ax = v.ax,data = df)

# %%
# Bar Plotting
sb.catplot(x = 'sex', y = 'survived', hue = 'class',kind = 'bar', data = titanic)

# %%
sb.catplot(x = 'sex', y = 'survived', hue = 'class',kind = 'point', data = titanic)

# %% [markdown]
# # Visualizing Distribution of Data

# %%
# Distplot
x = np.random.randn(100)
sb.distplot(x)

# %%
sb.distplot(x,kde = False,bins = 10)

# %%
sb.distplot(x,hist = False,bins = 10)

# %%
sb.kdeplot(x,shade = True)

# %%
# Jointplot
sb.jointplot(x = 'total_bill', y = 'tip', data = df)

# %%
sb.jointplot(x = 'total_bill', y = 'tip',kind = 'hex' ,data = df)

# %%
sb.jointplot(x = 'total_bill', y = 'tip',kind = 'kde' ,data = df)

# %%
# Pairplot
sb.pairplot(iris)

# %% [markdown]
# # Linear Regression Relationship

# %%
# Regplot
sb.regplot(x = 'total_bill', y = 'tip',data = df)

# %%
sb.lmplot(x = 'total_bill', y = 'tip',data = df)

# %%
sb.lmplot(x = 'size', y = 'tip',data = df)

# %%
sb.lmplot(x = 'size', y = 'tip',data = df, x_estimator= np.mean)

# %%
sb.lmplot(x = 'total_bill', y = 'tip',data = df, hue = 'sex', col = 'time',row = 'smoker')

# %%
sb.lineplot(x = )
